# %% [markdown]
# # 三菱地所のウェブサイトから物件情報を取得する

# %% [markdown]
# ## BeautifulSoupを使う

# %% [markdown]
# Referrence: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup
import requests

# %%
# URLを指定する
url = 'https://office.mec.co.jp/search/detail/928/'

# %%
# HTTPリクエストを発行する
# 参考： https://qiita.com/r_fukuma/items/a9e8d18467fe3e04068e
r = requests.get(url)

# %%
# BeautifulSoupでパースする
soup = BeautifulSoup(r.text, 'html.parser')

# %%
# データを見てみる。これが新丸ビルのページ
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]><html lang="ja" dir="ltr" class="no-js ie6 oldie"><![endif]-->
# <!--[if IE 7]><html lang="ja" dir="ltr" class="no-js ie7 oldie"><![endif]-->
# <!--[if IE 8]><html lang="ja" dir="ltr" class="no-js ie8 oldie"><![endif]-->
# <!--[if IE 9]><html lang="ja" dir="ltr" class="no-js ie9"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" dir="ltr" lang="ja"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1.0,maximum-scale=10.0,user-scalable=yes,initial-scale=1.0" name="viewport"/>
# <meta content="三菱地所,オフィス,オフィス情報,オフィスビル,賃貸オフィス,賃貸事務所,小規模オフィス,丸の内,大手町,有楽町" name="keywords"/>
# <meta content="【三菱地所公式】「新丸の内ビルディング（新丸ビル、新丸の内ビル）」のオフィスビル概要・アクセス・物件詳細、空室・事務所賃貸情報などをご覧いただけます。" name="description"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <link href="/assets/css/common/cmn_layout.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/common/cmn_style.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/common/style.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/common/cmn_print.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="/assets/js/common/jquery.js" type="text/javascript"></script>
# <script src="/assets/js/common/jquery.lazyload.min.js" type="text/javascript"></script>
# <script src="/assets/js/common/jquery.i18n.properties.min.js" type="text/javascript"></script>
# <script src="/assets/js/common/common.js" type="text/javascript"></script>
# <script src="/assets/js/common/common2.js" type="text/javascript"></script>
# <script src="/app/assets/js/search/search.js" type="text/javascript"></script>
# <!--[if lt IE 9]><script src="/assets/js/common/html5_ie.js"></script><![endif]-->
# <title>新丸の内ビルディング（新丸ビル、新丸の内ビル） | 三菱地所オフィス情報</title>
# <link href="/assets/css/search/results.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/search/detail_print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/search/jquery.bxslider.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/search/jquery.fancybox.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/search/jquery.qtip.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/assets/css/search/magnific-popup.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="/assets/js/search/jquery.bxslider.min.js"></script>
# <script src="/assets/js/search/match_height.js" type="text/javascript"></script>
# <script src="/assets/js/search/jquery.fancybox.js" type="text/javascript"></script>
# <script src="/assets/js/search/jquery.qtip.min.js" type="text/javascript"></script>
# <script src="/assets/js/search/jquery.magnific-popup.min.js" type="text/javascript"></script>
# <script src="/assets/js/search/custom_tooltip.js" type="text/javascript"></script>
# <script src="/assets/js/search/detail_scripts.js" type="text/javascript"></script>
# <script src="/app/assets/js/consumer.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(function(){
# 		$(".icoTooltip > a").customTooltip({ container: '.detailOverview01' });
# 	});
# </script>
# <script>
# var OfficeMec = OfficeMec || {};
# $(function() {
# 	OfficeMec.callPost = function(btnObj, sectionNo) {
# 		var url = btnObj.children('a:first').attr('href');
# 		return OfficeMec.createFormAndPost(url, function(form) {
# 			var input = document.createElement('input');
# 			$(form).append(sectionNo);
# 		});
# 	};
#
# 	$('.btnContact01').on('click', function() {
# 		var sectionNo = $('input[name=section_key\\[\\]]:checked').clone();
# 		if (sectionNo.length == 0) {
# 			// チェックボックスがチェックされていない場合、ビルコードのみをPOST
# 			sectionNo = $('input[name=section_key]').clone();
# 		};
# 		return OfficeMec.callPost($(this), sectionNo);
# 	});
#
# 	$('.btnContact02').on('click', function() {
# 		var sectionNo = $('input[name=section_key]').clone();
# 		return OfficeMec.callPost($(this), sectionNo);
# 	});
#
# 	// お気に入り追加処理
# 	$("#favBtn01, #favBtn02, #favBtn03").click(function() {
# 		var bldgCd = '928';
# 		var cookieName = 'favorite';
# 		var cookie = OfficeMec.getCookie(cookieName);
# 		var cookies = decodeURIComponent(cookie).split(',');
# 		if ($(this).hasClass('active')) {
# 			OfficeMec.appendCookieInArray(cookies, cookieName, bldgCd);
# 		} else {
# 			OfficeMec.deleteCookieInArray(cookies, cookieName, bldgCd);
# 		}
# 		return false;
# 	});
#
# 	// 履歴追加処理
# 	OfficeMec.appendHistory = function() {
# 		var bldgCd = '928';
# 		var cookieName = 'history';
# 		var cookie = OfficeMec.getCookie(cookieName);
# 		var cookies = decodeURIComponent(cookie).split(',');
# 		var deleteIndex = $.inArray(bldgCd, cookies);
# 		if (deleteIndex !== -1) {
# 			cookies.splice(deleteIndex, 1);
# 		}
# 		if (cookies.lengh >= 20) {
# 			cookies.splice(0, 1);
# 		}
# 		OfficeMec.appendCookieInArray(cookies, cookieName, bldgCd);
# 	};
# 	OfficeMec.appendHistory();
# });
# </script>
# </meta></head>
# <body class="searchDetail" id="catSearch">
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WNQD4B" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WNQD4B');</script>
# <!-- End Google Tag Manager --><div id="wrapper">
# <div id="headerWrap">
# <header id="header">
# <div class="innerWide01">
# <div id="headerLeft">
# <p id="headerLogo"><a href="/"><img alt="三菱地所 オフィス情報" src="/assets/img/common/logo01.png"/></a></p>
# <!-- /headerLeft --></div>
# <div id="headerRight">
# <div class="scrollable-area">
# <div id="headerUtility">
# <div class="header-utility">
# <div class="search-area forHead">
# <form accept-charset="utf-8" action="" method="GET">
# <input class="inputForm01" maxlength="100" name="keyword" placeholder="物件をキーワードで検索" type="text"/><input class="btnSearch01 btnWide01" type="button"/>
# </form> </div>
# <ul id="headerLang">
# <li><a class="current" href="/search/detail/928/">日本語</a></li><li><a href="/en/search/detail/928/">English</a></li>
# </ul>
# <ul class="listLink01" id="headerLinks">
# <li><a href="/search/history/"><i class="icoRecent01"></i>最近見た物件</a></li>
# <li><a href="/search/favorite/"><i class="icoFavorite01"></i>お気に入り物件</a></li>
# </ul>
# </div>
# <!-- /headerUtility --></div>
# <div class="contactInfoWrap01" id="headerContactInfo">
# <p class="btnContact01"><a href="https://office.mec.co.jp/inquiry/input" id="contactBtn-gNavi"><b>お問い合わせ・<br class="onlyPC"/>資料請求</b></a></p>
# <p class="contactInfo01">
# <span class="contactFreedial01"><b>0120-339-520</b></span>
# <span class="contactCelular01">携帯から<a href="tel:0332875310">03-3287-5310</a></span>
# <span class="contactOpeningHour01">平日 9:15～17:45</span>
# </p>
# <!-- /headerContactInfo --></div>
# <!--/scrollable-area--></div>
# <!-- /headerRight --></div>
# <p id="btnMenu">メニュー開閉</p>
# <!-- /innerWide01 --></div>
# </header>
# <nav id="gNav">
# <ul>
# <li id="gNav01"><a class="current"><b>オフィス物件・空室検索</b></a>
# <ul class="subMenu01">
# <li><a href="/search/area/">オフィス物件・空室検索</a></li>
# <li><a href="/search/lineup/">オフィスビル一覧</a></li>
# </ul>
# </li>
# <li id="gNav02"><a><b>小規模オフィス情報</b></a>
# <ul class="subMenu01">
# <li><a href="/small_office/">三菱地所の小規模オフィス</a></li>
# <li><a href="/small_office/office.html">小規模オフィス ラインアップ</a></li>
# <li><a href="/small_office/coworking.html">国内外成長企業向けコワーキングオフィス・ラボ</a></li>
# <li><a href="/small_office/the-premier-floor.html">The Premier Floor</a></li>
# <li><a href="/small_office/finolab.html">FINOLAB</a></li>
# <li><a href="/search/results/?area_max=100&amp;feature[]=2&amp;headline=2">小規模オフィスの空室を検索する</a></li>
# </ul>
# </li>
# <li id="gNav04"><a><b>三菱地所のオフィスビルコンセプト</b></a>
# <ul class="subMenu01">
# <li><a href="/concept/bcp.html">安全・安心・BCP</a></li>
# <li><a href="/concept/environment.html">いろいろな「働く」をサポート</a></li>
# <li><a href="/concept/amenity.html">楽しみを与えるオフィス環境</a></li>
# <li><a href="/concept/eco.html">環境への配慮と取り組み</a></li>
# </ul>
# </li>
# <li id="gNav05"><a><b>東京（丸の内・大手町・有楽町）エリアを知る</b></a>
# <ul class="subMenu01">
# <li><a href="/area/">世界有数のビジネス力</a></li>
# <li><a href="/area/amenity.html">賑わいの街</a></li>
# <li><a href="/area/history.html">歴史</a></li>
# </ul>
# </li>
# <li class="hasNoMenu01" id="gNav06"><a href="/step/"><b>ご入居までのステップ</b></a></li>
# </ul>
# <!-- /gNavi --></nav>
# <!-- /headerWrap --></div>
# <nav id="localNavTop">
# <ul class="localNav01">
# <li><a class="current" href="/search/area/">オフィス物件・空室検索</a></li>
# <li><a href="/search/lineup/">オフィスビル一覧</a></li>
# </ul>
# <!-- /localNavTop --></nav>
# <div class="contactPrint01">
# <p>お問い合わせ</p>
# <p>【フリーダイヤル】0120-339-520 【携帯から】03-3287-5310　※平日9:15～17:45</p>
# </div>
# <div id="contents">
# <article id="main">
# <div class="headingArea01">
# <p class="logo_details01 onlyPC"><a href="
# http://www.marunouchi.com/top/shinmaru" target="_blank"><img alt="" height="96" src="/bldg_img/928/928_commerce_01_142x96_b.jpg" width="142"/></a></p>
# <h1>新丸の内ビルディング（新丸ビル、新丸の内ビル）</h1>
# <!-- /headingArea01 --></div>
# <section class="sectionSearchWrap01" id="tabs">
# <section class="sectionSearch01">
# <div class="inner">
# <p class="txt_lessThan01 onlyPC"><span><img alt="" height="10" src="/assets/img/common/blank.png" width="6"/></span></p>
# <ul class="iconFavorite">
# <li class="first"><a class="" href="#" id="favBtn01"><i class="icoFav01"></i>お気に入りに追加</a></li>
# <li class="last onlyPC"><a href="#" id="printBtn01"><i class="icoFav02"></i>印刷する</a></li>
# </ul>
# <ul class="menuCondition01 tabs">
# <li><a class="current" href="#tabs01"><i class="icoInformation01"></i>基本情報</a></li>
# <li><a href="#tabs02"><i class="icoMap01"></i>アクセス・周辺環境</a></li>
# <li><a href="#tabs03"><i class="icoDetail01"></i>詳細情報</a></li>
# </ul>
# <!-- /inner --></div>
# <!-- /section --></section>
# <form action="" method="post">
# <input name="section_key" type="hidden" value="1-928">
# <section class="sectionSearch02 type01">
# <ul class="iconSideBar01 onlyPC">
# <li><a href="#" id="contactBtn02" onclick="$('#tabs01 .btnContact01').trigger('click');return false;"><img alt="お問い合わせ" height="54" src="/assets/img/search/common/iconSideBar01.png" width="59"/></a></li>
# <li><a href="#" onclick="$('#tabs01 .btnContact02').trigger('click');return false;"><img alt="空室お知らせ" height="54" src="/assets/img/search/common/iconSideBar02.png" width="59"/></a></li>
# <li><a class="" href="#" id="favBtn02"></a></li>
# <li><a href="#" id="printBtn02"><img alt="印刷する" height="54" src="/assets/img/search/common/iconSideBar04.png" width="59"/></a></li>
# </ul>
# <div class="boxDetailTab01" id="tabs01">
# <div class="inner">
# <h2 class="ttlSearch03 type01">新丸の内ビルディングの概要</h2>
# <div class="boxSearchDetail01 clearfix">
# <div class="secOverview01 clearfix">
# <div class="imageOverview01">
# <img alt="新丸の内ビルディングの概要" src="/bldg_img/928/928_exterior_01_280x_a.jpg" srcset="/bldg_img/928/928_exterior_01_280x_a.jpg 1x, /bldg_img/928/928_exterior_01_560x_a.jpg 2x"/>
# </div>
# <div class="detailOverview01">
# <ul class="ul_listIcon01">
# <li>
# <p class="icon">
# <title>飲食施設充実</title>
# <img height="32" src="/assets/img/search/common/icon_sectionMap01.png" width="32"/>
# </p>
# <p class="detail"><span>飲食施設充実</span></p>
# </li>
# <li>
# <p class="icon">
# <title>小規模面積あり</title>
# <img height="32" src="/assets/img/search/common/icon_sectionMap02_no.png" width="32"/>
# </p>
# <p class="detail"><span>小規模面積あり</span></p>
# </li>
# <li>
# <p class="icon">
# <title>雨に濡れない</title>
# <img height="32" src="/assets/img/search/common/icon_sectionMap03.png" width="32"/>
# </p>
# <p class="detail"><span>雨に濡れない</span></p>
# </li>
# <li>
# <p class="icon">
# <title>VIP対応（車寄せ、単独EV）</title>
# <img height="32" src="/assets/img/search/common/icon_sectionMap04.png" width="32"/>
# </p>
# <p class="detail"><span>VIP対応（車寄せ、単独EV）</span></p>
# </li>
# <li>
# <p class="icon">
# <title>BCP充実</title>
# <img height="32" src="/assets/img/search/common/icon_sectionMap05_no.png" width="32"/>
# </p>
# <p class="detail"><span>BCP充実</span></p>
# </li>
# <li>
# <p class="icon">
# <title>セキュリティーゲート有/設置可</title>
# <img height="32" src="/assets/img/search/common/icon_sectionMap06.png" width="32"/>
# </p>
# <p class="detail"><span>セキュリティーゲート有/設置可</span></p>
# </li>
# <li>
# <p class="icon">
# <title>土日開館</title>
# <img height="32" src="/assets/img/search/common/icon_sectionMap07_no.png" width="32"/>
# </p>
# <p class="detail"><span>土日開館</span></p>
# </li>
# <li class="icoTooltip"><a href="#"><img alt="?" height="21" src="/assets/img/search/common/ico_tooltip01.png" width="20"/></a></li>
# </ul>
# <ul class="ul_detail01 type01">
# <li>
# <dl>
# <dt>所在地</dt>
# <dd>東京都千代田区丸の内１－５－１</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>竣工年月</dt>
# <dd>2007年4月 (平成19年4月)</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>規模</dt>
# <dd>地上 38階・地下 4階・塔屋 1階</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>アクセス</dt>
# <dd>JR、東京メトロ丸ノ内線「東京駅」直結</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>ショップサイト</dt>
# <dd class="txt_linkMap01"><a href="
# http://www.marunouchi.com/top/shinmaru" target="_blank">
# http://www.marunouchi.com/top/shinmaru</a></dd>
# </dl>
# </li>
# </ul>
# <ul class="txt_linkMap02">
# <li><a class="scroll" href="#wantedProp"><span><img alt="" height="6" src="/assets/img/search/common/arrow_underRed01.png" width="10"/></span>このビルの募集中物件</a></li>
# <li><a class="scroll" href="#placeNearby"><span><img alt="" height="6" src="/assets/img/search/common/arrow_underRed01.png" width="10"/></span>環境が近いオフィスビル物件</a></li>
# </ul>
# </div>
# <aside class="contentSet01">
# <div class="boxWhite01 type02">
# <p class="taL taL_sp">丸ビルに並んで丸の内エリアを代表する、正にランドマークビルです。名実ともに当社の基幹物件として君臨しております。黒を基調にしたスタイリッシュな外観は見るものを圧倒します。ハイグレードなオフィススペックに加えて、テナント専用のラウンジにはフィットネスやカフェ等充実したサポート施設を用意。プレミア感を感じさせてくれます。また飲食店も充実しており、７階の丸の内ハウスでは朝４時まで営業しております。ついつい夜更かししてみるのもいいかもしれません。</p>
# <!-- /boxWhite01 --></div>
# </aside>
# <div class="boxImgPopUp01 clearfix">
# <h3><b class="style01">ギャラリー</b></h3>
# <div class="imgPopUpslider01">
# <ul class="slider">
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_01_800x800_a.jpg" rel="gallery1" title=""><span><img alt="" src="/bldg_img/928/928_gallery_01_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_01_100x100_b.jpg 1x, /bldg_img/928/928_gallery_01_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_02_800x800_a.jpg" rel="gallery1" title="エントランス"><span><img alt="エントランス" src="/bldg_img/928/928_gallery_02_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_02_100x100_b.jpg 1x, /bldg_img/928/928_gallery_02_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_03_800x800_a.jpg" rel="gallery1" title="ジム"><span><img alt="ジム" src="/bldg_img/928/928_gallery_03_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_03_100x100_b.jpg 1x, /bldg_img/928/928_gallery_03_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_04_800x800_a.jpg" rel="gallery1" title="セキュリティゲート"><span><img alt="セキュリティゲート" src="/bldg_img/928/928_gallery_04_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_04_100x100_b.jpg 1x, /bldg_img/928/928_gallery_04_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_05_800x800_a.jpg" rel="gallery1" title="ラウンジ1"><span><img alt="ラウンジ1" src="/bldg_img/928/928_gallery_05_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_05_100x100_b.jpg 1x, /bldg_img/928/928_gallery_05_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_06_800x800_a.jpg" rel="gallery1" title="ラウンジ2"><span><img alt="ラウンジ2" src="/bldg_img/928/928_gallery_06_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_06_100x100_b.jpg 1x, /bldg_img/928/928_gallery_06_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_07_800x800_a.jpg" rel="gallery1" title="事務室"><span><img alt="事務室" src="/bldg_img/928/928_gallery_07_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_07_100x100_b.jpg 1x, /bldg_img/928/928_gallery_07_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_08_800x800_a.jpg" rel="gallery1" title="会議室"><span><img alt="会議室" src="/bldg_img/928/928_gallery_08_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_08_100x100_b.jpg 1x, /bldg_img/928/928_gallery_08_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_09_800x800_a.jpg" rel="gallery1" title="会議室2"><span><img alt="会議室2" src="/bldg_img/928/928_gallery_09_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_09_100x100_b.jpg 1x, /bldg_img/928/928_gallery_09_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_10_800x800_a.jpg" rel="gallery1" title="商業"><span><img alt="商業" src="/bldg_img/928/928_gallery_10_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_10_100x100_b.jpg 1x, /bldg_img/928/928_gallery_10_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_11_800x800_a.jpg" rel="gallery1" title="基準階エレベーターホール"><span><img alt="基準階エレベーターホール" src="/bldg_img/928/928_gallery_11_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_11_100x100_b.jpg 1x, /bldg_img/928/928_gallery_11_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_12_800x800_a.jpg" rel="gallery1" title="廊下"><span><img alt="廊下" src="/bldg_img/928/928_gallery_12_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_12_100x100_b.jpg 1x, /bldg_img/928/928_gallery_12_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_13_800x800_a.jpg" rel="gallery1" title="男子ロッカー"><span><img alt="男子ロッカー" src="/bldg_img/928/928_gallery_13_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_13_100x100_b.jpg 1x, /bldg_img/928/928_gallery_13_200x200_b.jpg 2x"/></span></a></li>
# <li><a class="fancybox-effects-a" href="/bldg_img/928/928_gallery_14_800x800_a.jpg" rel="gallery1" title="車寄せ"><span><img alt="車寄せ" src="/bldg_img/928/928_gallery_14_100x100_b.jpg" srcset="/bldg_img/928/928_gallery_14_100x100_b.jpg 1x, /bldg_img/928/928_gallery_14_200x200_b.jpg 2x"/></span></a></li>
# </ul>
# </div>
# </div>
# <!-- /secOverview01 clearfix --></div>
# <!-- /boxSearchDetail02 --></div>
# <div class="boxSearchDetail02">
# <h2 class="ttlSearch03">基準階プラン</h2>
# <div class="boxDetailFloor01">
# <div class="col01">
# <div class="boxFloorImg01">
# <p class="ico01"><img src="/assets/img/search/detail/ico_zoom01.png"/></p>
# <p class="imgFloor01"><a class="fancybox-effects-a" href="/bldg_img/928/928_std_plan_01_680x500_b.jpg"><img alt="基準階プラン" src="/bldg_img/928/928_std_plan_01_280x260_b.jpg" srcset="/bldg_img/928/928_std_plan_01_280x260_b.jpg 1x, /bldg_img/928/928_std_plan_01_560x520_b.jpg 2x"/></a></p>
# <!-- /boxFloorImg01 --></div>
# <!-- /col01 --></div>
# <div class="col02">
# <ul class="ul_detail01 type01">
# <li>
# <dl>
# <dt>床面積</dt>
# <dd>2,900.00㎡ (877.25坪)～3,200.00㎡ (968.00坪)</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>床荷重</dt>
# <dd>標準 500kg/㎡　特別　800kg/㎡</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>天井高</dt>
# <dd>2,850mm（ＯＡフロア設置後）</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>コンセント容量</dt>
# <dd>75VA/㎡</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>OAフロア</dt>
# <dd>有　高さ150mm<br>特殊階　天井高：3,000mm＋OAフロア300mm<br/>コア区画は別</br></dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>トイレ</dt>
# <dd>男女各1カ所</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>給湯室</dt>
# <dd>各2カ所</dd>
# </dl>
# </li>
# </ul>
# <!-- /col02 --></div>
# <!-- /boxDetailFloor01 --></div>
# <!-- /boxSearchDetail02 --></div>
# <div class="boxSearchDetail02" id="wantedProp">
# <h2 class="ttlSearch03">募集中物件</h2>
# <aside class="contentSet01">
# <div class="boxWhite01 type01">
# <p class="taC taL_sp">ご要望に合わせて物件をご紹介いたします。お気軽にご相談ください。</p>
# <div class="buttonArea01">
# <p class="btnContact01 btnWide01"><a href="https://office.mec.co.jp/inquiry/input" id="contactBtn01_1"><b>物件についてのお問い合わせはこちら</b></a></p>
# </div>
# <!-- /boxWhite01 --></div>
# </aside>
# <aside class="contentSet01 type01">
# <div class="boxWhite01">
# <p class="taC taL_sp">ご希望のオフィスビル物件が空き次第メールでお知らせします。</p>
# <div class="buttonArea01">
# <p class="btnContact02 btnWide01"><a href="https://office.mec.co.jp/search/vacancy_notice/input"><b>空室お知らせメールのお受け取りはこちら</b></a></p>
# </div>
# <!-- /boxWhite01 --></div>
# </aside>
# <p class="linkProperty01" style="margin-top:10px; margin-bottom:0;"><a href="/small_office/office.html">小規模オフィス ラインアップはこちら</a></p>
# <!-- /boxSearchDetail02 --></div>
# <!-- /inner --></div>
# <!-- /boxSearchTab01 --></div>
# <div class="boxDetailTab02" id="tabs02">
# <div class="inner">
# <h2 class="ttlSearch03">アクセスマップ</h2>
# <div class="secMapBox01">
# <div class="map">
# <div class="mapFrame" style="overflow:auto;">
# <iframe allowfullscreen="" frameborder="0" height="600" src="https://maps.google.co.jp/maps?key=AIzaSyBa2Eko-0d1cYW4lNZUdvSsSEuPGH2vpVE&amp;ll=35.682561,139.764292&amp;q=loc:35.682561,139.764292&amp;output=embed&amp;t=m&amp;z=16" style="border:0; margin-top: -100px;" width="100%"></iframe> </div>
# </div>
# <div class="details">
# <h3><b class="style01">アクセスマップ（略図）</b></h3>
# <div class="imageMap">
# <a class="fancybox-map" href="/bldg_img/928/928_map_01_635x425_b.jpg"><img alt="アクセスマップ（略図）" height="200" src="/bldg_img/928/928_map_01_300x200_b.jpg" srcset="/bldg_img/928/928_map_01_300x200_b.jpg 1x, /bldg_img/928/928_map_01_600x400_b.jpg 2x" width="300"/></a>
# </div>
# <p class="btn_zoomMap"><a class="fancybox-map" href="/bldg_img/928/928_map_01_635x425_b.jpg"><b>拡大</b></a></p>
# <dl class="place_details01">
# <dt>所在地</dt>
# <dd><p>東京都千代田区丸の内１－５－１</p></dd>
# <dt>アクセス</dt>
# <dd><p>JR、東京メトロ丸ノ内線「東京駅」直結</p></dd>
# </dl>
# <p class="txt_linkMap01"><a href="https://www.google.com/maps?ll=35.682561,139.764292&amp;q=loc:35.682561,139.764292&amp;z=18&amp;t=m&amp;hl=ja&amp;gl=JP&amp;mapclient=embed" rel="noreferrer" target="_blank"><span><img alt="" height="10" src="/assets/img/search/common/arrow_gtRed01.png" width="6"/></span>Googleマップで表示</a></p>
# </div>
# </div>
# <div class="secImageBox01">
# <h2>周辺環境</h2>
# <div class="picViewMap01">
# <div class="streetView" id="streetView">
# <iframe allowfullscreen="" frameborder="0" height="100%" src="https://www.google.com/maps/embed?key=AIzaSyBa2Eko-0d1cYW4lNZUdvSsSEuPGH2vpVE&amp;pb=!1m0!3m2!1sja!2sjp!4v1453185853172!6m8!1m7!1smfK_ZKkDqx1VG5kvjeuFiw!2m2!1d35.68301802238986!2d139.7650658219305!3f232.37!4f18.25!5f1.0008212265978327" style="border:0" width="100%"></iframe> </div>
# </div>
# <p class="txt_linkMap01 type01"><a href="https://www.google.co.jp/maps/@35.683018,139.7650658,3a,66.8y,232.37h,108.25t/data=!3m4!1e1!3m2!1smfK_ZKkDqx1VG5kvjeuFiw!2e0" rel="noreferrer" target="_blank"><span><img alt="" height="10" src="/assets/img/search/common/arrow_gtRed01.png" width="6"/></span>Googleストリートビューで表示</a></p>
# <aside class="contentSet01">
# <div class="boxWhite01 type01">
# <p class="taC taL_sp">サイトに掲載している物件以外にもご要望に合わせた物件をご紹介できる場合がございます。お気軽にご相談ください。</p>
# <div class="buttonArea01">
# <p class="btnContact01 btnWide01"><a href="https://office.mec.co.jp/inquiry/input" id="contactBtn01_2"><b>物件についてのお問い合わせはこちら</b></a></p>
# </div>
# <!-- /boxWhite01 --></div>
# </aside>
# </div>
# <!-- /inner --></div>
# <!-- /boxSearchTab01 --></div>
# <div class="boxDetailTab03" id="tabs03">
# <div class="inner">
# <h2 class="ttlSearch03">ビル詳細</h2>
# <ul class="ul_detail01">
# <li>
# <dl>
# <dt>ビル名称</dt>
# <dd>新丸の内ビルディング</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>所在地</dt>
# <dd>東京都千代田区丸の内１－５－１</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>アクセス</dt>
# <dd>JR、東京メトロ丸ノ内線「東京駅」直結</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>竣工年月</dt>
# <dd>2007年4月 (平成19年4月)</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>規模</dt>
# <dd>地上 38階・地下 4階・塔屋 1階</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>構造</dt>
# <dd>鉄骨造・一部鉄骨鉄筋コンクリート造</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>延床面積</dt>
# <dd>193,685.62㎡ (58,589.90坪)</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>有効面積</dt>
# <dd>97,750.53㎡ (29,569.54坪)</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>敷地面積</dt>
# <dd>9,983.09㎡ (3,019.88坪)</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>建物高さ</dt>
# <dd>最高軒高 176.7ｍ 最高部 197.6ｍ</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>設計監理</dt>
# <dd>三菱地所設計</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>エレベーター</dt>
# <dd>乗用 32台　貨物用 2台</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>空調設備</dt>
# <dd>フロア毎に複数ゾーニング可<br/>２４時間供給可能</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>基準冷暖房供給<br/>時間（事務所）</dt>
# <dd>平日 8:30~19:00<br>土曜 設定無し<br/>日祝 設定無し</br></dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>リフレッシュコーナー</dt>
# <dd>有</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>通信インフラ</dt>
# <dd>光ファイバ敷設済<br/>高速インターネットサービス利用可</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>開閉館時間</dt>
# <dd>平日 6:00-24:30<br/>土曜 Closed<br/>日祝 Closed</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>管理形態</dt>
# <dd>２４時間有人管理</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>夜間入退館方法</dt>
# <dd>カードによる入退館</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>ガレージ収容台数</dt>
# <dd>368台 (高さ 3,000mm)</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>ガレージ営業時間</dt>
# <dd>全日 24hours<br/>定期契約車は24時間入出庫可</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>公式ホームページ</dt>
# <dd class="txt_linkMap01"><a href="
# http://www.marunouchi.com/top/shinmaru" target="_blank">
# http://www.marunouchi.com/top/shinmaru</a></dd>
# </dl>
# </li>
# </ul>
# <aside class="contentSet01">
# <div class="boxWhite01 type01">
# <p class="taC taL_sp">サイトに掲載している物件以外にもご要望に合わせた物件をご紹介できる場合がございます。お気軽にご相談ください。</p>
# <div class="buttonArea01">
# <p class="btnContact01 btnWide01"><a href="https://office.mec.co.jp/inquiry/input" id="contactBtn01_3"><b>物件についてのお問い合わせはこちら</b></a></p>
# </div>
# <!-- /boxWhite01 --></div>
# </aside>
# <!-- /inner --></div>
# <!-- /boxSearchTab01 --></div>
# <!-- /sectionSearch02 --></section>
# </input></form>
# <div class="secList01">
# <div class="listIn">
# <div class="showListIn01" id="placeNearby">
# <h3><b class="type01">環境が近いオフィスビル物件</b></h3>
# <div id="slider01">
# <ul class="slider listProperty01">
# <li>
# <p class="img01"><img alt="" height="70" src="/bldg_img/952/952_exterior_01_60x70_b.jpg" width="60"/></p>
# <p class="txt_head01"><a href="/search/detail/952/">丸の内パークビルディング</a></p>
# <p class="txt_detail01">千代田区丸の内２－６－１<br/>2009年4月 (平成21年4月)<br/>地上 34階・地下 4階・塔屋 3階<br/>ＪＲ、東京メトロ丸ノ内線「東京駅」より徒歩5分</p>
# </li>
# <li>
# <p class="img01"><img alt="" height="70" src="/bldg_img/916/916_exterior_01_60x70_b.jpg" width="60"/></p>
# <p class="txt_head01"><a href="/search/detail/916/">丸の内ビルディング</a></p>
# <p class="txt_detail01">千代田区丸の内２－４－１<br/>2002年8月 (平成14年8月)<br/>地上 37階・地下 4階・塔屋 2階<br/>ＪＲ、東京メトロ丸ノ内線「東京駅」直結<br>東京メトロ千代田線「二重橋前駅」より徒歩２分</br></p>
# </li>
# <li>
# <p class="img01"><img alt="" height="70" src="/bldg_img/927/927_exterior_01_60x70_b.jpg" width="60"/></p>
# <p class="txt_head01"><a href="/search/detail/927/">東京ビルディング</a></p>
# <p class="txt_detail01">千代田区丸の内２－７－３<br/>2005年10月 (平成17年10月)<br/>地上 33階・地下 4階・塔屋 1階<br/>ＪＲ、東京メトロ丸ノ内線「東京駅」より徒歩１分<br>東京メトロ有楽町線「有楽町駅」より徒歩５分</br></p>
# </li>
# </ul>
# <!-- /slider01 --></div>
# <!-- / .showListIn01 --></div>
# <!-- / .listIn --></div>
# <!-- / .secList01 --></div>
# <!-- /sectionSearchWrap01 --></section>
# <!-- /main --></article>
# <!-- /contents --></div>
# <nav id="localNavBottom">
# <ul class="localNav01">
# <li><a class="current" href="/search/area/">オフィス物件・空室検索</a></li>
# <li><a href="/search/lineup/">オフィスビル一覧</a></li>
# </ul>
# <!-- /localNavBottom --></nav>
# <footer id="footer">
# <div id="footerTop">
# <div class="innerNormal01">
# <nav id="footerTopNav">
# <ul>
# <li><strong>オフィス物件・空室検索</strong>
# <ul class="listLink02">
# <li><a href="/search/area/">オフィス物件・空室検索</a></li>
# <li><a href="/search/lineup/">オフィスビル一覧</a></li>
# </ul>
# </li>
# <li><strong>小規模オフィス情報</strong>
# <ul class="listLink02">
# <li><a href="/small_office/">三菱地所の小規模オフィス</a></li>
# <li><a href="/small_office/office.html">小規模オフィス ラインアップ</a></li>
# <li><a href="/small_office/coworking.html">国内外成長企業向けコワーキングオフィス・ラボ</a></li>
# <li><a href="/small_office/the-premier-floor.html">The Premier Floor</a></li>
# <li><a href="/small_office/finolab.html">FINOLAB</a></li>
# <li><a href="/search/results/?area_max=100&amp;feature[]=2&amp;headline=2">小規模オフィスの空室を検索する</a></li>
# </ul>
# </li>
# <li><strong>三菱地所のオフィスビルコンセプト</strong>
# <ul class="listLink02">
# <li><a href="/concept/bcp.html">安全・安心・BCP</a></li>
# <li><a href="/concept/environment.html">いろいろな「働く」をサポート</a></li>
# <li><a href="/concept/amenity.html">楽しみを与えるオフィス環境</a></li>
# <li><a href="/concept/eco.html">環境への配慮と取り組み</a></li>
# </ul>
# </li>
# <li><strong>東京（丸の内・大手町・有楽町）エリアを知る</strong>
# <ul class="listLink02">
# <li><a href="/area/">世界有数のビジネス力</a></li>
# <li><a href="/area/amenity.html">賑わいの街</a></li>
# <li><a href="/area/history.html">歴史</a></li>
# </ul>
# </li>
# </ul>
# <!-- /footerTopNav --></nav>
# <nav id="footerTopNav02">
# <ul class="listLink02">
# <li><a href="/step/">ご入居までのステップ</a></li>
# </ul>
# <!-- /footerTopNav02 --></nav>
# <dl id="recommendedInfo02">
# <dt>おすすめ物件情報</dt>
# <dd>
# <ul>
# <li class="first"><a href="/small_office/" target="_blank"><img alt="小規模オフィス情報" class="lazy" data-original="/assets/img/common/pic_recommended-small.png" src="/assets/img/common/pic_recommended-small.png" style="display: inline;"/></a></li>
# <li><a href="/tokiwabashi/" target="_blank"><img alt="TOKYO TOKIWABASHI 東京駅前常盤橋プロジェクト 眺めが変わる。世界が広がる。" class="lazy" data-original="/assets/img/common/pic_recommended-tokiwabashi.png" src="/assets/img/common/pic_recommended-tokiwabashi.png" style="display: inline;"/></a></li>
# <li><a href="/hibiya_kokusai/" target="_blank"><img alt="日比谷国際ビル" class="lazy" data-original="/assets/img/common/pic_recommended-hibiya.png" src="/assets/img/common/pic_recommended-hibiya.png" style="display: inline;"/></a></li>
# <li class="last"><a href="/msb-tamachi/" target="_blank"><img alt="DESIGN BUSINESS 新しい働き方の実現 msb田町" class="lazy" data-original="/assets/img/common/pic_recommended-msb.png" src="/assets/img/common/pic_recommended-msb.png" style="display: inline;"/></a></li>
# </ul>
# </dd>
# <!-- /recommendInfo -->
# </dl> <div class="contactInfoWrap01" id="footerTopContactInfo">
# <p class="btnContact01"><a href="https://office.mec.co.jp/inquiry/input" id="contactBtn-footer"><b>お問い合わせ・<br class="onlyPCTB"/>資料請求</b></a></p>
# <p class="contactInfo01">
# <span class="contactFreedial01"><b>0120-339-520</b></span>
# <span class="contactCelular01">携帯から<a href="tel:0332875310">03-3287-5310</a></span>
# <span class="contactOpeningHour01">平日 9:15～17:45</span>
# </p>
# <!-- /footerTopContactInfo --></div>
# <ul class="listLink01" id="footerTopLinks">
# <li><a href="http://www.mec.co.jp/" target="_blank">三菱地所</a></li>
# <li><a href="http://www.marunouchi.com/" target="_blank">Marunouchi.com</a></li>
# <li><a href="http://marunouchi.mec.co.jp/jp/" target="_blank">MARUNOUCHI - THE HEART OF TOKYO -</a></li>
# <li><a href="http://www.egg-japan.com/" target="_blank">EGG JAPAN</a></li>
# <li><a href="http://www.gbh-tokyo.or.jp/" target="_blank">グローバルビジネスハブ東京</a></li>
# <li><a href="http://www.e-officepark.jp/" target="_blank">三菱地所リアルエステートサービス</a></li>
# <li><a href="http://www.mjpm.co.jp/" target="_blank">三菱地所プロパティマネジメント</a></li>
# <!-- /footerTopLinks --></ul>
# <!-- /innerNormal01 --></div>
# <!-- /footerTop --></div>
# <div id="footerBottom">
# <div class="innerWide01">
# <div id="footerBottomLeft">
# <ul class="listLink01" id="footerBottomLinks">
# <li><a href="/terms/">利用規約</a></li>
# <!-- /footerBottomLinks --></ul>
# <p id="copyright"><small>Copyright ©Mitsubishi Estate Co., ltd. All rights reserved.</small></p>
# <!-- /footerBottomLeft --></div>
# <div id="footerBottomRight">
# <p id="footerLogo"><a href="http://www.mec.co.jp/" target="_blank"><img alt="人を、想う力。街を、想う力。三菱地所" height="38" src="/assets/img/common/logo02.png" width="110"/></a></p>
# <!-- /footerBottomRight --></div>
# <!-- /innerWide01 --></div>
# <!-- /footerBottom --></div>
# </footer><!-- /wrapper --></div>
# <div class="btnWrapper">
# <div class="btnFavorite"><a href="#" id="favBtn03">お気に入りに追加</a></div>
# <div class="btnContact03"><a href="#" id="contactBtn03" onclick="$('#tabs01 .btnContact01').trigger('click');return false;">この物件についてお問い合わせ</a></div>
# </div>
# <div class="modalFav is-hide">
# <p class="txtFav">お気に入りに<br>追加されました</br></p>
# </div>
# <p class="is-close" id="spMenu"><a href="">Menu Open/Close</a></p>
# <p class="scroll" id="pageTop"><a href="#wrapper">▲</a></p>
# <script type="text/javascript">
# var OfficeMec = OfficeMec || {};
# $(function(){
# 	OfficeMec.is_en = ('' == '1');
# });
# </script>
# </body>
# </html>

# %%
# 物件名称を取得するために<title>タグを取ってくる
soup.select('title')
# Out:
# [<title>新丸の内ビルディング（新丸ビル、新丸の内ビル） | 三菱地所オフィス情報</title>,
#  <title>飲食施設充実</title>,
#  <title>小規模面積あり</title>,
#  <title>雨に濡れない</title>,
#  <title>VIP対応（車寄せ、単独EV）</title>,
#  <title>BCP充実</title>,
#  <title>セキュリティーゲート有/設置可</title>,
#  <title>土日開館</title>]

# %%
# どうやら配列の一番最初の項目が物件名称っぽいので取ってくる
soup.select('title')[0]
# Out:
# <title>新丸の内ビルディング（新丸ビル、新丸の内ビル） | 三菱地所オフィス情報</title>

# %%
# 中の文字列だけ取ってくる
soup.select('title')[0].string
# Out:
# '新丸の内ビルディング（新丸ビル、新丸の内ビル） | 三菱地所オフィス情報'

# %%
# | 以降が邪魔なので、' | 'で分割してみる
soup.select('title')[0].string.split(' | ')
# Out:
# ['新丸の内ビルディング（新丸ビル、新丸の内ビル）', '三菱地所オフィス情報']

# %%
# 最初のやつが物件名称なので取ってきて name という変数に入れる
name = soup.select('title')[0].string.split(' | ')[0]
name
# Out:
# '新丸の内ビルディング（新丸ビル、新丸の内ビル）'

# %%
# 次に、延床面積と有効面積はどうやら<dt><dd>タグに入ってるっぽいから取ってくる
dts = soup.select('dt')
dds = soup.select('dd')

# %%
# dtsの中身を見てみる
dts
# Out:
# [<dt>所在地</dt>,
#  <dt>竣工年月</dt>,
#  <dt>規模</dt>,
#  <dt>アクセス</dt>,
#  <dt>ショップサイト</dt>,
#  <dt>床面積</dt>,
#  <dt>床荷重</dt>,
#  <dt>天井高</dt>,
#  <dt>コンセント容量</dt>,
#  <dt>OAフロア</dt>,
#  <dt>トイレ</dt>,
#  <dt>給湯室</dt>,
#  <dt>所在地</dt>,
#  <dt>アクセス</dt>,
#  <dt>ビル名称</dt>,
#  <dt>所在地</dt>,
#  <dt>アクセス</dt>,
#  <dt>竣工年月</dt>,
#  <dt>規模</dt>,
#  <dt>構造</dt>,
#  <dt>延床面積</dt>,
#  <dt>有効面積</dt>,
#  <dt>敷地面積</dt>,
#  <dt>建物高さ</dt>,
#  <dt>設計監理</dt>,
#  <dt>エレベーター</dt>,
#  <dt>空調設備</dt>,
#  <dt>基準冷暖房供給<br/>時間（事務所）</dt>,
#  <dt>リフレッシュコーナー</dt>,
#  <dt>通信インフラ</dt>,
#  <dt>開閉館時間</dt>,
#  <dt>管理形態</dt>,
#  <dt>夜間入退館方法</dt>,
#  <dt>ガレージ収容台数</dt>,
#  <dt>ガレージ営業時間</dt>,
#  <dt>公式ホームページ</dt>,
#  <dt>おすすめ物件情報</dt>]

# %%
# ddsも見てみる
dds
# Out:
# [<dd>東京都千代田区丸の内１－５－１</dd>,
#  <dd>2007年4月 (平成19年4月)</dd>,
#  <dd>地上 38階・地下 4階・塔屋 1階</dd>,
#  <dd>JR、東京メトロ丸ノ内線「東京駅」直結</dd>,
#  <dd class="txt_linkMap01"><a href="
#  http://www.marunouchi.com/top/shinmaru" target="_blank">
#  http://www.marunouchi.com/top/shinmaru</a></dd>,
#  <dd>2,900.00㎡ (877.25坪)～3,200.00㎡ (968.00坪)</dd>,
#  <dd>標準 500kg/㎡　特別　800kg/㎡</dd>,
#  <dd>2,850mm（ＯＡフロア設置後）</dd>,
#  <dd>75VA/㎡</dd>,
#  <dd>有　高さ150mm<br>特殊階　天井高：3,000mm＋OAフロア300mm<br/>コア区画は別</br></dd>,
#  <dd>男女各1カ所</dd>,
#  <dd>各2カ所</dd>,
#  <dd><p>東京都千代田区丸の内１－５－１</p></dd>,
#  <dd><p>JR、東京メトロ丸ノ内線「東京駅」直結</p></dd>,
#  <dd>新丸の内ビルディング</dd>,
#  <dd>東京都千代田区丸の内１－５－１</dd>,
#  <dd>JR、東京メトロ丸ノ内線「東京駅」直結</dd>,
#  <dd>2007年4月 (平成19年4月)</dd>,
#  <dd>地上 38階・地下 4階・塔屋 1階</dd>,
#  <dd>鉄骨造・一部鉄骨鉄筋コンクリート造</dd>,
#  <dd>193,685.62㎡ (58,589.90坪)</dd>,
#  <dd>97,750.53㎡ (29,569.54坪)</dd>,
#  <dd>9,983.09㎡ (3,019.88坪)</dd>,
#  <dd>最高軒高 176.7ｍ 最高部 197.6ｍ</dd>,
#  <dd>三菱地所設計</dd>,
#  <dd>乗用 32台　貨物用 2台</dd>,
#  <dd>フロア毎に複数ゾーニング可<br/>２４時間供給可能</dd>,
#  <dd>平日 8:30~19:00<br>土曜 設定無し<br/>日祝 設定無し</br></dd>,
#  <dd>有</dd>,
#  <dd>光ファイバ敷設済<br/>高速インターネットサービス利用可</dd>,
#  <dd>平日 6:00-24:30<br/>土曜 Closed<br/>日祝 Closed</dd>,
#  <dd>２４時間有人管理</dd>,
#  <dd>カードによる入退館</dd>,
#  <dd>368台 (高さ 3,000mm)</dd>,
#  <dd>全日 24hours<br/>定期契約車は24時間入出庫可</dd>,
#  <dd class="txt_linkMap01"><a href="
#  http://www.marunouchi.com/top/shinmaru" target="_blank">
#  http://www.marunouchi.com/top/shinmaru</a></dd>,
#  <dd>
#  <ul>
#  <li class="first"><a href="/small_office/" target="_blank"><img alt="小規模オフィス情報" class="lazy" data-original="/assets/img/common/pic_recommended-small.png" src="/assets/img/common/pic_recommended-small.png" style="display: inline;"/></a></li>
#  <li><a href="/tokiwabashi/" target="_blank"><img alt="TOKYO TOKIWABASHI 東京駅前常盤橋プロジェクト 眺めが変わる。世界が広がる。" class="lazy" data-original="/assets/img/common/pic_recommended-tokiwabashi.png" src="/assets/img/common/pic_recommended-tokiwabashi.png" style="display: inline;"/></a></li>
#  <li><a href="/hibiya_kokusai/" target="_blank"><img alt="日比谷国際ビル" class="lazy" data-original="/assets/img/common/pic_recommended-hibiya.png" src="/assets/img/common/pic_recommended-hibiya.png" style="display: inline;"/></a></li>
#  <li class="last"><a href="/msb-tamachi/" target="_blank"><img alt="DESIGN BUSINESS 新しい働き方の実現 msb田町" class="lazy" data-original="/assets/img/common/pic_recommended-msb.png" src="/assets/img/common/pic_recommended-msb.png" style="display: inline;"/></a></li>
#  </ul>
#  </dd>]

# %%
# dtsとddsを対応させて、{'key': 'value'}という辞書を作ってresultsという変数に入れる
results = {
    k.text: v.text for k, v in zip(dts, dds)
}
results
# Out:
# {'所在地': '東京都千代田区丸の内１－５－１',
#  '竣工年月': '2007年4月 (平成19年4月)',
#  '規模': '地上 38階・地下 4階・塔屋 1階',
#  'アクセス': 'JR、東京メトロ丸ノ内線「東京駅」直結',
#  'ショップサイト': '\r\nhttp://www.marunouchi.com/top/shinmaru',
#  '床面積': '2,900.00㎡ (877.25坪)～3,200.00㎡ (968.00坪)',
#  '床荷重': '標準 500kg/㎡\u3000特別\u3000800kg/㎡',
#  '天井高': '2,850mm（ＯＡフロア設置後）',
#  'コンセント容量': '75VA/㎡',
#  'OAフロア': '有\u3000高さ150mm特殊階\u3000天井高：3,000mm＋OAフロア300mmコア区画は別',
#  'トイレ': '男女各1カ所',
#  '給湯室': '各2カ所',
#  'ビル名称': '新丸の内ビルディング',
#  '構造': '鉄骨造・一部鉄骨鉄筋コンクリート造',
#  '延床面積': '193,685.62㎡ (58,589.90坪)',
#  '有効面積': '97,750.53㎡ (29,569.54坪)',
#  '敷地面積': '9,983.09㎡ (3,019.88坪)',
#  '建物高さ': '最高軒高 176.7ｍ 最高部 197.6ｍ',
#  '設計監理': '三菱地所設計',
#  'エレベーター': '乗用 32台\u3000貨物用 2台',
#  '空調設備': 'フロア毎に複数ゾーニング可２４時間供給可能',
#  '基準冷暖房供給時間（事務所）': '平日 8:30~19:00土曜 設定無し日祝 設定無し',
#  'リフレッシュコーナー': '有',
#  '通信インフラ': '光ファイバ敷設済高速インターネットサービス利用可',
#  '開閉館時間': '平日 6:00-24:30土曜 Closed日祝 Closed',
#  '管理形態': '２４時間有人管理',
#  '夜間入退館方法': 'カードによる入退館',
#  'ガレージ収容台数': '368台 (高さ 3,000mm)',
#  'ガレージ営業時間': '全日 24hours定期契約車は24時間入出庫可',
#  '公式ホームページ': '\r\nhttp://www.marunouchi.com/top/shinmaru',
#  'おすすめ物件情報': '\n\n\n\n\n\n\n'}

# %%
# results['key']で value を取得できるので、所在地、延床面積、有効面積を取得する
address = results['所在地']
gfa = results['延床面積']
nla = results['有効面積']

# %%
address
# Out:
# '東京都千代田区丸の内１－５－１'

# %%
gfa
# Out:
# '193,685.62㎡ (58,589.90坪)'

# %%
nla
# Out:
# '97,750.53㎡ (29,569.54坪)'

# %%
# GFAとNLAは㎡以降が邪魔なので、㎡でsplitとして最初の要素を取得する
gfa = results['延床面積'].split('㎡')[0]
nla = results['有効面積'].split('㎡')[0]

print(gfa)
print(nla)
# Out:
# 193,685.62
# 97,750.53

# %%
# 少数(float)にするために','を''(空文字)に変換する
gfa = results['延床面積'].split('㎡')[0].replace(',', '')
nla = results['有効面積'].split('㎡')[0].replace(',', '')

print(gfa)
print(nla)
# Out:
# 193685.62
# 97750.53

# %%
# 少数に変更する
gfa = float(results['延床面積'].split('㎡')[0].replace(',', ''))
nla = float(results['有効面積'].split('㎡')[0].replace(',', ''))

print(gfa)
print(nla)
# Out:
# 193685.62
# 97750.53

# %%
import pandas as pd

# %%
# 一つデータフレームを作ってみる
data = pd.DataFrame({
      '物件名称': [name],
      '所在地': [address],
      '延床面積': [gfa],
      '有効面積': [nla]
  })
data
# Out:
#                       物件名称              所在地       延床面積      有効面積
# 0  新丸の内ビルディング（新丸ビル、新丸の内ビル）  東京都千代田区丸の内１－５－１  193685.62  97750.53

# %% [markdown]
# ## 全ての物件情報を取得してDataFrameに入れる

# %%
# 最初にProperty_codeを書いておきます
property_codes = ['506', '507', '513', '514', '522', '524', '525', '526', '527', '530', 
                                '531', '543', '544', '551', '867', '869',  '873', '874', '875', '905',
                                '915', '916', '917', '922', '927', '928', '952', '959', '984', '988',
                                'Z02', '5A2', '5C5', '5C6', '5D1', '5J1']

# %%
# 空の配列を作ってこれにデータを入れていく
df = []

# for文で順番に処理する
for property_code in property_codes:
    # 今何の処理をしているか表示する
    print("property_code: %s" % property_code)
    
    url = 'https://office.mec.co.jp/search/detail/' + property_code
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    
    name = soup.select('title')[0].string.split(' | ')[0]
    
    dts = soup.select('dt')
    dds = soup.select('dd')
    results = {
        k.text: v.text for k, v in zip(dts, dds)
    }
    
    address = results['所在地']
    gfa = float(results.get('延床面積', "0").split('㎡')[0].replace(",", ""))
    nla = float(results.get('有効面積', "0").split('㎡')[0].replace(",", ""))
    
    data = pd.DataFrame({
        '物件コード': [property_code],
        '物件名称': [name],
        '所在地': [address],
        '延床面積': [gfa],
        '有効面積': [nla]
    })
    
    # さっき作った空の配列にデータを入れていく
    df.append(data)

df = pd.concat(df)
# Out:
# property_code: 506
# property_code: 507
# property_code: 513
# property_code: 514
# property_code: 522
# property_code: 524
# property_code: 525
# property_code: 526
# property_code: 527
# property_code: 530
# property_code: 531
# property_code: 543
# property_code: 544
# property_code: 551
# property_code: 867
# property_code: 869
# property_code: 873
# property_code: 874
# property_code: 875
# property_code: 905
# property_code: 915
# property_code: 916
# property_code: 917
# property_code: 922
# property_code: 927
# property_code: 928
# property_code: 952
# property_code: 959
# property_code: 984
# property_code: 988
# property_code: Z02
# property_code: 5A2
# property_code: 5C5
# property_code: 5C6
# property_code: 5D1
# property_code: 5J1

# %%
# DataFrameを確認する
df
# Out:
#   物件コード                             物件名称                      所在地       延床面積  \
# 0   506                     丸の内二丁目ビル（丸二）          東京都千代田区丸の内２－５－１   45985.39
# 0   507                     丸の内仲通りビル（丸仲）          東京都千代田区丸の内２－２－３   46102.20
# 0   513                             三菱ビル          東京都千代田区丸の内２－５－２   60434.55
# 0   514                             岸本ビル          東京都千代田区丸の内２－２－１   33972.00
# 0   522                    新東京ビル（新東京、新東）          東京都千代田区丸の内３－３－１  102768.18
# 0   524                       新国際ビル（新国際）          東京都千代田区丸の内３－４－１   77484.41
# 0   525                         国際ビル（国際）          東京都千代田区丸の内３－１－１   76918.25
# 0   526                      新有楽町ビル（新有楽）         東京都千代田区有楽町１－１２－１   83023.27
# 0   527                        有楽町ビル（有楽）         東京都千代田区有楽町１－１０－１   42159.08
# 0   530                      有楽町電気ビル（有電）          東京都千代田区有楽町１－７－１   71142.00
# 0   531                       新日石ビル（新日石）          東京都千代田区丸の内３－４－２   26565.60
# 0   543                            大手町ビル          東京都千代田区大手町１－６－１  111272.00
# 0   544                      新大手町ビル（新大手）          東京都千代田区大手町２－２－１   88785.00
# 0   551                          ＪＦＥ商事ビル          東京都千代田区大手町２－７－１   14270.98
# 0   867                            経団連会館          東京都千代田区大手町１－３－２   54709.00
# 0   869                        朝日生命大手町ビル          東京都千代田区大手町２－６－１   49295.96
# 0   873                            パレスビル          東京都千代田区丸の内１－１－１   66850.00
# 0   874  大手町フィナンシャルシティノースタワー（フィナンシャルノース）          東京都千代田区大手町１－９－５  109618.81
# 0   875  大手町フィナンシャルシティサウスタワー（フィナンシャルサウス）          東京都千代田区大手町１－９－７  133156.14
# 0   905                  丸の内永楽ビルディング（永楽）          東京都千代田区丸の内１－４－１  139684.30
# 0   915             丸の内北口ビルディング（丸北、北口ビル）          東京都千代田区丸の内１－６－５   65564.51
# 0   916                   丸の内ビルディング（丸ビル）          東京都千代田区丸の内２－４－１  159901.38
# 0   917          日本工業倶楽部会館・三菱ＵＦＪ信託銀行本店ビル      東京都千代田区丸の内一丁目４番５、６号  109915.72
# 0   922                         明治安田生命ビル          東京都千代田区丸の内２－１－１  147134.43
# 0   927                    東京ビルディング（東ビル）          東京都千代田区丸の内２－７－３  147213.03
# 0   928          新丸の内ビルディング（新丸ビル、新丸の内ビル）          東京都千代田区丸の内１－５－１  193685.62
# 0   952             丸の内パークビルディング（丸の内パーク）          東京都千代田区丸の内２－６－１  195593.04
# 0   959                        ＪＰタワー（JP）          東京都千代田区丸の内２－７－２  212000.00
# 0   984                         ＪＡビル（ＪＡ）          東京都千代田区大手町１－３－１   79734.00
# 0   988                     大和呉服橋ビル（呉服橋）          東京都千代田区大手町２－６－４   24452.74
# 0   Z02                         丸の内二重橋ビル          東京都千代田区丸の内３－２－３       0.00
# 0   5A2                          西新橋スクエア           東京都港区西新橋一丁目３－１   55372.73
# 0   5C5                           大手門タワー          東京都千代田区大手町１－１－２  107571.33
# 0   5C6             大手町パークビルディング（大手町パーク）          東京都千代田区大手町１－１－１  151708.02
# 0   5D1    大手町フィナンシャルシティグランキューブ（グランキューブ）        東京都千代田区大手町一丁目９番２号  193800.00
# 0   5J1                  東京駅前常盤橋プロジェクトＡ棟  東京都千代田区大手町二丁目、中央区八重洲一丁目  146000.00
#
#         有効面積
# 0   31086.43
# 0   29226.05
# 0   37242.25
# 0    8741.77
# 0   71710.17
# 0   40709.36
# 0   41579.03
# 0   51433.83
# 0   22799.14
# 0   24432.76
# 0    5318.05
# 0   62967.03
# 0   58065.79
# 0   10482.20
# 0   15403.68
# 0   27128.60
# 0   43205.59
# 0   27166.45
# 0   58312.12
# 0   48929.28
# 0   52534.40
# 0   72884.24
# 0   39875.07
# 0   42212.46
# 0   82145.09
# 0   97750.53
# 0  115608.21
# 0   93126.36
# 0   32965.29
# 0   16241.06
# 0       0.00
# 0   17213.92
# 0   43488.97
# 0   69027.23
# 0  129700.73
# 0       0.00

# %% [markdown]
# ## データを整形する

# %%
# 二重橋ビルの面積がゼロなの木になる。。。
df[df.物件名称 == "丸の内二重橋ビル"]
# Out:
#   物件コード      物件名称              所在地  延床面積  有効面積
# 0   Z02  丸の内二重橋ビル  東京都千代田区丸の内３－２－３   0.0   0.0

# %%
# https://office.mec.co.jp/news_file/25/mec181121_nijjubashi.pdf
# 延床面積はどうやら 174054.18 ㎡っぽいので代入する
df.loc[df.物件名称 == "丸の内二重橋ビル", "延床面積"] = 174054.18

# %%
df
# Out:
#   物件コード                             物件名称                      所在地       延床面積  \
# 0   506                     丸の内二丁目ビル（丸二）          東京都千代田区丸の内２－５－１   45985.39
# 0   507                     丸の内仲通りビル（丸仲）          東京都千代田区丸の内２－２－３   46102.20
# 0   513                             三菱ビル          東京都千代田区丸の内２－５－２   60434.55
# 0   514                             岸本ビル          東京都千代田区丸の内２－２－１   33972.00
# 0   522                    新東京ビル（新東京、新東）          東京都千代田区丸の内３－３－１  102768.18
# 0   524                       新国際ビル（新国際）          東京都千代田区丸の内３－４－１   77484.41
# 0   525                         国際ビル（国際）          東京都千代田区丸の内３－１－１   76918.25
# 0   526                      新有楽町ビル（新有楽）         東京都千代田区有楽町１－１２－１   83023.27
# 0   527                        有楽町ビル（有楽）         東京都千代田区有楽町１－１０－１   42159.08
# 0   530                      有楽町電気ビル（有電）          東京都千代田区有楽町１－７－１   71142.00
# 0   531                       新日石ビル（新日石）          東京都千代田区丸の内３－４－２   26565.60
# 0   543                            大手町ビル          東京都千代田区大手町１－６－１  111272.00
# 0   544                      新大手町ビル（新大手）          東京都千代田区大手町２－２－１   88785.00
# 0   551                          ＪＦＥ商事ビル          東京都千代田区大手町２－７－１   14270.98
# 0   867                            経団連会館          東京都千代田区大手町１－３－２   54709.00
# 0   869                        朝日生命大手町ビル          東京都千代田区大手町２－６－１   49295.96
# 0   873                            パレスビル          東京都千代田区丸の内１－１－１   66850.00
# 0   874  大手町フィナンシャルシティノースタワー（フィナンシャルノース）          東京都千代田区大手町１－９－５  109618.81
# 0   875  大手町フィナンシャルシティサウスタワー（フィナンシャルサウス）          東京都千代田区大手町１－９－７  133156.14
# 0   905                  丸の内永楽ビルディング（永楽）          東京都千代田区丸の内１－４－１  139684.30
# 0   915             丸の内北口ビルディング（丸北、北口ビル）          東京都千代田区丸の内１－６－５   65564.51
# 0   916                   丸の内ビルディング（丸ビル）          東京都千代田区丸の内２－４－１  159901.38
# 0   917          日本工業倶楽部会館・三菱ＵＦＪ信託銀行本店ビル      東京都千代田区丸の内一丁目４番５、６号  109915.72
# 0   922                         明治安田生命ビル          東京都千代田区丸の内２－１－１  147134.43
# 0   927                    東京ビルディング（東ビル）          東京都千代田区丸の内２－７－３  147213.03
# 0   928          新丸の内ビルディング（新丸ビル、新丸の内ビル）          東京都千代田区丸の内１－５－１  193685.62
# 0   952             丸の内パークビルディング（丸の内パーク）          東京都千代田区丸の内２－６－１  195593.04
# 0   959                        ＪＰタワー（JP）          東京都千代田区丸の内２－７－２  212000.00
# 0   984                         ＪＡビル（ＪＡ）          東京都千代田区大手町１－３－１   79734.00
# 0   988                     大和呉服橋ビル（呉服橋）          東京都千代田区大手町２－６－４   24452.74
# 0   Z02                         丸の内二重橋ビル          東京都千代田区丸の内３－２－３  174054.18
# 0   5A2                          西新橋スクエア           東京都港区西新橋一丁目３－１   55372.73
# 0   5C5                           大手門タワー          東京都千代田区大手町１－１－２  107571.33
# 0   5C6             大手町パークビルディング（大手町パーク）          東京都千代田区大手町１－１－１  151708.02
# 0   5D1    大手町フィナンシャルシティグランキューブ（グランキューブ）        東京都千代田区大手町一丁目９番２号  193800.00
# 0   5J1                  東京駅前常盤橋プロジェクトＡ棟  東京都千代田区大手町二丁目、中央区八重洲一丁目  146000.00
#
#         有効面積
# 0   31086.43
# 0   29226.05
# 0   37242.25
# 0    8741.77
# 0   71710.17
# 0   40709.36
# 0   41579.03
# 0   51433.83
# 0   22799.14
# 0   24432.76
# 0    5318.05
# 0   62967.03
# 0   58065.79
# 0   10482.20
# 0   15403.68
# 0   27128.60
# 0   43205.59
# 0   27166.45
# 0   58312.12
# 0   48929.28
# 0   52534.40
# 0   72884.24
# 0   39875.07
# 0   42212.46
# 0   82145.09
# 0   97750.53
# 0  115608.21
# 0   93126.36
# 0   32965.29
# 0   16241.06
# 0       0.00
# 0   17213.92
# 0   43488.97
# 0   69027.23
# 0  129700.73
# 0       0.00
