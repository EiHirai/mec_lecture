# %%
import pandas as pd

# %%
df = pd.read_csv('mec_property.csv')
df
# Out:
#     Unnamed: 0 物件コード                             物件名称                  所在地  \
# 0            0   506                     丸の内二丁目ビル（丸二）      東京都千代田区丸の内２－５－１
# 1            1   507                     丸の内仲通りビル（丸仲）      東京都千代田区丸の内２－２－３
# 2            2   513                             三菱ビル      東京都千代田区丸の内２－５－２
# 3            3   514                             岸本ビル      東京都千代田区丸の内２－２－１
# 4            4   522                    新東京ビル（新東京、新東）      東京都千代田区丸の内３－３－１
# 5            5   524                       新国際ビル（新国際）      東京都千代田区丸の内３－４－１
# 6            6   525                         国際ビル（国際）      東京都千代田区丸の内３－１－１
# 7            7   526                      新有楽町ビル（新有楽）     東京都千代田区有楽町１－１２－１
# 8            8   527                        有楽町ビル（有楽）     東京都千代田区有楽町１－１０－１
# 9            9   530                      有楽町電気ビル（有電）      東京都千代田区有楽町１－７－１
# 10          10   531                       新日石ビル（新日石）      東京都千代田区丸の内３－４－２
# 11          11   543                            大手町ビル      東京都千代田区大手町１－６－１
# 12          12   544                      新大手町ビル（新大手）      東京都千代田区大手町２－２－１
# 13          13   551                          ＪＦＥ商事ビル      東京都千代田区大手町２－７－１
# 14          14   867                            経団連会館      東京都千代田区大手町１－３－２
# 15          15   869                        朝日生命大手町ビル      東京都千代田区大手町２－６－１
# 16          16   873                            パレスビル      東京都千代田区丸の内１－１－１
# 17          17   874  大手町フィナンシャルシティノースタワー（フィナンシャルノース）      東京都千代田区大手町１－９－５
# 18          18   875  大手町フィナンシャルシティサウスタワー（フィナンシャルサウス）      東京都千代田区大手町１－９－７
# 19          19   905                  丸の内永楽ビルディング（永楽）      東京都千代田区丸の内１－４－１
# 20          20   915             丸の内北口ビルディング（丸北、北口ビル）      東京都千代田区丸の内１－６－５
# 21          21   916                   丸の内ビルディング（丸ビル）      東京都千代田区丸の内２－４－１
# 22          22   917          日本工業倶楽部会館・三菱ＵＦＪ信託銀行本店ビル  東京都千代田区丸の内一丁目４番５、６号
# 23          23   922                         明治安田生命ビル      東京都千代田区丸の内２－１－１
# 24          24   927                    東京ビルディング（東ビル）      東京都千代田区丸の内２－７－３
# 25          25   928          新丸の内ビルディング（新丸ビル、新丸の内ビル）      東京都千代田区丸の内１－５－１
# 26          26   952             丸の内パークビルディング（丸の内パーク）      東京都千代田区丸の内２－６－１
# 27          27   959                        ＪＰタワー（JP）      東京都千代田区丸の内２－７－２
# 28          28   984                         ＪＡビル（ＪＡ）      東京都千代田区大手町１－３－１
# 29          29   988                     大和呉服橋ビル（呉服橋）      東京都千代田区大手町２－６－４
# 30          30   Z02                         丸の内二重橋ビル      東京都千代田区丸の内３－２－３
# 31          31   5A2                          西新橋スクエア       東京都港区西新橋一丁目３－１
# 32          32   5C5                           大手門タワー      東京都千代田区大手町１－１－２
# 33          33   5C6             大手町パークビルディング（大手町パーク）      東京都千代田区大手町１－１－１
# 34          34   5D1    大手町フィナンシャルシティグランキューブ（グランキューブ）    東京都千代田区大手町一丁目９番２号
# 35          35   5J1                  東京駅前常盤橋プロジェクトＡ棟      東京都千代田区大手町2-6-3
#
#          延床面積       有効面積         緯度          経度
# 0    45985.39   31086.43  35.680003  139.763182
# 1    46102.20   29226.05  35.680232  139.762595
# 2    60434.55   37242.25  35.679911  139.763610
# 3    33972.00    8741.77  35.680124  139.761996
# 4   102768.18   71710.17  35.677503  139.762953
# 5    77484.41   40709.36  35.676702  139.762064
# 6    76918.25   41579.03  35.676760  139.761109
# 7    83023.27   51433.83  35.675572  139.761971
# 8    42159.08   22799.14  35.674932  139.761763
# 9    71142.00   24432.76  35.674588  139.761515
# 10   26565.60    5318.05  35.676708  139.762599
# 11  111272.00   62967.03  35.686398  139.764855
# 12   88785.00   58065.79  35.684917  139.767108
# 13   14270.98   10482.20  35.686229  139.769493
# 14   54709.00   15403.68  35.688663  139.763553
# 15   49295.96   27128.60  35.684409  139.769068
# 16   66850.00   43205.59  35.684500  139.761221
# 17  109618.81   27166.45  35.688250  139.766158
# 18  133156.14   58312.12  35.687691  139.765819
# 19  139684.30   48929.28  35.684356  139.764932
# 20   65564.51   52534.40  35.683957  139.766888
# 21  159901.38   72884.24  35.680976  139.763784
# 22  109915.72   39875.07  35.683709  139.764674
# 23  147134.43   42212.46  35.678842  139.762066
# 24  147213.03   82145.09  35.678607  139.764936
# 25  193685.62   97750.53  35.682543  139.764287
# 26  195593.04  115608.21  35.678570  139.762533
# 27  212000.00   93126.36  35.679746  139.764784
# 28   79734.00   32965.29  35.688692  139.762799
# 29   24452.74   16241.06  35.684055  139.770587
# 30  174054.18       0.00  35.677990  139.761910
# 31   55372.73   17213.92  35.669142  139.754506
# 32  107571.33   43488.97  35.686064  139.761993
# 33  151708.02   69027.23  35.686724  139.762621
# 34  193800.00  129700.73  35.688781  139.764566
# 35  146000.00       0.00  35.684465  139.770307

# %% [markdown]
# ## Foliumを使う

# %%
import folium

# %%
folium_map = folium.Map(location=[35.682543, 139.764287], # 新丸ビルを中心とする
                        zoom_start=15,
                        tiles="CartoDB dark_matter")

# %%
# 見てみる
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 第2回でやったように地図に描画
folium_mec = folium.Map(location=[35.682543, 139.764287], # 新丸ビルを中心とする
                        zoom_start=15,
                        tiles="CartoDB dark_matter")

for index, row in df.iterrows():
    try:
        gross_floor_area = row['延床面積']
        gross_floor_area =  gross_floor_area / 5000
        radius = gross_floor_area # 延床面積が大きいほど円が大きくなるように半径を設定しておく

        popup_text ="""
                        物件名称: {}<br>
                        所在地: {}<br>
                        延床面積: {}
                        """
        popup_text = popup_text.format(
                                        row['物件名称'],
                                        row['所在地'],
                                        gross_floor_area
                                      )
        
        color="#0A8A9F" # ティール
        
        folium.CircleMarker(location=(row['緯度'], row['経度']),
                                                            radius=radius,
                                                            color=color,
                                                            fill=True,
                                                            popup=popup_text
                                           ).add_to(folium_mec) # 最初に定義しているfolium_mapというオブジェクトにデータを加える
    except ValueError:
        print(index)

# %%
folium_mec
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# HTMLファイルを保存
folium_mec.save("./mec_gfa_distribution.html")
