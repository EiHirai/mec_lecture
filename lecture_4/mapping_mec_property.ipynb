# %%
import pandas as pd

# %%
df = pd.read_csv('mec_property.csv')
df
# Out:
#     Unnamed: 0                           物件名称                    所在地  \
# 0            0                       丸の内二重橋ビル        東京都千代田区丸の内３－２－３
# 1            1           大手町パークビルディング（大手町パーク）        東京都千代田区大手町１－１－１
# 2            2  大手町フィナンシャルシティグランキューブ（グランキューブ）      東京都千代田区大手町一丁目９番２号
# 3            3                東京駅前常盤橋プロジェクトＡ棟        東京都千代田区大手町2-6-3
# 4            4                      大名古屋ビルヂング  愛知県名古屋市中村区名駅三丁目２８番１２号
# 5            5                   丸の内二丁目ビル（丸二）        東京都千代田区丸の内２－５－１
# 6            6                   丸の内仲通りビル（丸仲）        東京都千代田区丸の内２－２－３
# 7            7                           三菱ビル        東京都千代田区丸の内２－５－２
# 8            8                           岸本ビル        東京都千代田区丸の内２－２－１
# 9            9                  新東京ビル（新東京、新東）        東京都千代田区丸の内３－３－１
# 10          10                     新国際ビル（新国際）        東京都千代田区丸の内３－４－１
# 11          11                       国際ビル（国際）        東京都千代田区丸の内３－１－１
# 12          12                     新日石ビル（新日石）        東京都千代田区丸の内３－４－２
# 13          13                          パレスビル        東京都千代田区丸の内１－１－１
# 14          14                丸の内永楽ビルディング（永楽）        東京都千代田区丸の内１－４－１
# 15          15           丸の内北口ビルディング（丸北、北口ビル）        東京都千代田区丸の内１－６－５
# 16          16                 丸の内ビルディング（丸ビル）        東京都千代田区丸の内２－４－１
# 17          17        日本工業倶楽部会館・三菱ＵＦＪ信託銀行本店ビル    東京都千代田区丸の内一丁目４番５、６号
# 18          18                       明治安田生命ビル        東京都千代田区丸の内２－１－１
# 19          19                  東京ビルディング（東ビル）        東京都千代田区丸の内２－７－３
# 20          20        新丸の内ビルディング（新丸ビル、新丸の内ビル）        東京都千代田区丸の内１－５－１
# 21          21           丸の内パークビルディング（丸の内パーク）        東京都千代田区丸の内２－６－１
# 22          22                      ＪＰタワー（JP）        東京都千代田区丸の内２－７－２
# 23          23                    新有楽町ビル（新有楽）       東京都千代田区有楽町１－１２－１
# 24          24                      有楽町ビル（有楽）       東京都千代田区有楽町１－１０－１
# 25          25                    有楽町電気ビル（有電）        東京都千代田区有楽町１－７－１
# 26          26                        西新橋スクエア         東京都港区西新橋一丁目３－１
# 27          27                          大手町ビル        東京都千代田区大手町１－６－１
# 28          28                    新大手町ビル（新大手）        東京都千代田区大手町２－２－１
# 29          29                        ＪＦＥ商事ビル        東京都千代田区大手町２－７－１
# ..         ...                            ...                    ...
# 61          61            ＳＰＰ銀座ビル（SPP銀座\nSPP）          東京都中央区銀座２－４－９
# 62          62         新宿イーストサイドスクエア（イーストサイド）        東京都新宿区新宿６－２７－３０
# 63          63              大崎フロントタワー（大崎フロント）          東京都品川区大崎１－２－１
# 64          64               アイケイビルディング（アイケイ）        東京都品川区上大崎２－２４－９
# 65          65               ＳＯＵＴＨＧＡＴＥ新宿（サウス）       東京都渋谷区千駄ヶ谷５－３３－８
# 66          66              新宿フロントタワー（新宿フロント）        東京都新宿区北新宿２－２１－１
# 21  195593.04  115608.21  35.679129  139.763122
# 22  212000.00   93126.36  35.679717  139.764757
# 23   83023.27   51433.83  35.675691  139.761900
# 24   42159.08   22799.14  35.675013  139.761759
# 25   71142.00   24432.76  35.674413  139.761234
# 26   55372.73   17213.92  35.669313  139.754401
# 27  111272.00   62967.03  35.686295  139.764219
# 28   88785.00   58065.79  35.685276  139.767055
# 29   14270.98   10482.20  35.686265  139.769474
# ..        ...        ...        ...         ...
# 61    3199.03    2259.46  35.673724  139.766136
# 62  170220.33  116894.56  35.696798  139.708573
# 63   24125.01   16856.93  35.621854  139.728080
# 64   21105.00   12134.05  35.635436  139.714106
# 65   17077.33   12635.02  35.687430  139.703405
# 66   93996.52   57979.87  35.695990  139.689369
# 67  101502.57   67126.99  35.657574  139.794784
# 68  106951.80   72581.52  35.656882  139.795608
# 69  392884.85  209115.17  35.455750  139.631676
# 70   91414.00   28201.37  35.455864  139.633103
# 71   51979.00   38468.77  35.458578  139.632367
# 72   25951.21   18051.75  43.063945  141.350410
# 73   27176.72   18374.32  43.069697  141.351698
# 74   12562.73    8069.51  43.069278  141.348854
# 75   13439.54    9080.50  43.062148  141.350510
# 76    8751.47    5044.43  38.265156  140.867833
# 77   19718.91   11134.38  38.267012  140.869014
# 78   40711.59   23180.16  38.265518  140.880373
# 79   19865.49   10080.07  38.259588  140.873230
# 80   48567.45   23830.39  36.580022  136.645177
# 81   14575.87    8415.84  35.172808  136.899968
# 82   27227.54   12096.20  35.172863  136.900871
# 83    8757.55    6077.16  34.734860  135.497037
# 84   24346.20    8388.81  34.691810  135.504032
# 85   68491.19   40919.25  34.702296  135.500150
# 86  257963.53   86509.15  34.699979  135.519858
# 87   14436.95    8763.16  34.387949  132.454559
# 88   11479.99       0.00  34.394646  132.466222
# 89    9970.04    6637.80  34.394005  132.464174
# 90   36135.71   10960.18  34.390566  132.455353
#
# [91 rows x 7 columns]

# %% [markdown]
# ## Foliumを使う

# %%
import folium

# %%
folium_map = folium.Map(location=[35.682543, 139.764287], # 新丸ビルを中心とする
                        zoom_start=15,
                        tiles="cartodbpositron")

# %%
# 見てみる
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 第2回でやったように地図に描画
folium_mec = folium.Map(location=[35.682543, 139.764287], # 新丸ビルを中心とする
                        zoom_start=15,
                        tiles="cartodbpositron")

for index, row in df.iterrows():
    try:
        gross_floor_area = row['延床面積']
        gross_floor_area =  gross_floor_area / 5000
        radius = gross_floor_area # 延床面積が大きいほど円が大きくなるように半径を設定しておく

        popup_text ="""
                        物件名称: {}<br>
                        所在地: {}<br>
                        延床面積: {}
                        """
        popup_text = popup_text.format(
                                        row['物件名称'],
                                        row['所在地'],
                                        gross_floor_area
                                      )
        
        color="#0A8A9F" # ティール
        
        folium.CircleMarker(location=(row['latitude'], row['longitude']),
                                                            radius=radius,
                                                            color=color,
                                                            fill=True,
                                                            popup=popup_text
                                           ).add_to(folium_mec) # 最初に定義しているfolium_mapというオブジェクトにデータを加える
    except ValueError:
        print(index)

# %%
folium_mec
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# HTMLファイルを保存
folium_mec.save("./mec_gfa_distribution.html")
